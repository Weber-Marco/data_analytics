# %% [markdown]
# # Writing data to and reading data from a Database using Python

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import sqlite3
import fnmatch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Function to close a sqlite db-connection
def check_conn(conn):
     try:
        conn.cursor()
        return True
     except Exception as ex:
        return False

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_02

# %% [markdown]
# ## Create sqlite data base

# %%
# Create data base
conn = sqlite3.connect('supermarket_database.db') 
cursor = conn.cursor()

# Show dbs in the directory
flist = fnmatch.filter(os.listdir('.'), '*.db')
for i in flist:
    print(i)
# Out:
# supermarket_database.db
# apartment_database.db

# %% [markdown]
# ## Create SQL-table in the database

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS supermarket_table (id VARCHAR(50),
                                                               lat DECIMAL(16,8),
                                                               lon DECIMAL(16,8),
                                                               brand VARCHAR(255),
                                                               shop VARCHAR(255),
                                                            city VARCHAR(255),  
                                                            street VARCHAR(255),
                                                        housenumber VARCHAR(255),   
                                                            postcode VARCHAR(255))''')  
            
# Confirm changes to the table
conn.commit()

# %% [markdown]
# ## Read data from file to data frame

# %%
df = pd.read_csv('supermarkets_data_prepared.csv', 
                  sep=',', 
                  encoding='utf-8')[['id', 'lat', 'lon', 'brand', 'shop', 'city', 'street', 'housenumber', 'postcode']]
print(df.shape)
df.head(5)
# Out:
# (3392, 9)
#          id        lat       lon   brand         shop    city          street  \
# 0  33126515  47.155616  9.037915    Spar  supermarket     NaN             NaN
# 1  36726161  47.226191  8.980329  Migros  supermarket  Uznach  Zürcherstrasse
# 2  39768209  47.225069  8.969981    Coop  supermarket  Uznach             NaN
# 3  39947904  47.376732  8.542161    Coop  supermarket  Zürich   Bahnhofbrücke
# 4  48932835  47.375020  8.522895  Migros  supermarket  Zürich    Wengistrasse
#
#   housenumber  postcode
# 0         NaN       NaN
# 1          25    8730.0
# 2         NaN    8730.0
# 3           1    8001.0
# 4           7    8004.0

# %% [markdown]
# ## Write data to the SQL-table in data base

# %%
df.to_sql(name = 'supermarket_table',
          con = conn,
          index = False,
          if_exists = 'replace')
# Out:
# 3392

# %% [markdown]
# ## Query the SQL-table

# %%
# Query the SQL-table
cursor.execute('''SELECT *
               FROM supermarket_table
               WHERE rooms >=1''')

df = pd.DataFrame(cursor.fetchall(), 
                  columns=['id', 'lat', 'lon', 'brand', 'shop', 'city', 'street', 'housenumber', 'postcode'])    
df
# Out:
#              OrderId                                            Address  \
# 0       1693998201-1                  Neuhusstrasse 6, 8630 Rüti ZH, ZH
# 1       1693998201-2                 Zürcherstrasse 1, 8173 Neerach, ZH
# 2       1693998201-4                Cramerstrasse 8-12, 8004 Zürich, ZH
# 3       1693998201-5                  Rotachstrasse 33, 8003 Zürich, ZH
# 4      1693998201-16                    Wolframplatz 1, 8045 Zürich, ZH
# ..               ...                                                ...
# 958  1693998381-1004               Hölderlinstrasse 12, 8032 Zürich, ZH
# 959  1693998381-1005  Hegifeldstrasse 70, 8404 Reutlingen (Winterthu...
# 960  1693998381-1006           Holzmoosrütisteig 2b, 8820 Wädenswil, ZH
# 961  1693998381-1007           Vogelbuckstrasse 25, 8307 Effretikon, ZH
# 962  1693998381-1008                  Maneggstrasse 83, 8041 Zürich, ZH
#
#      Rooms   Area   Price
# 0      3.0   49.0  1441.0
# 1      3.5   65.0  1850.0
# 2      2.0   54.0  4853.0
# 3      2.0   49.0  4335.0
# 4      2.0   32.0  3515.0
# ..     ...    ...     ...
# 958    3.5   82.0  2830.0
# 959    4.0   73.0  1713.0
# 960    4.5  110.0  3500.0
# 961    3.0   68.0  1650.0
# 962    4.5  114.0  3262.0
#
# [963 rows x 5 columns]

# %% [markdown]
# ### Additional SQL-queries

# %%
cursor.execute('''SELECT *
                  FROM supermarket_table
                  WHERE city = "Winterthur"''')

df_winterthur = pd.DataFrame(cursor.fetchall(), 
                             columns=['id', 'lat', 'lon', 'brand', 'shop', 'city', 'street', 'housenumber', 'postcode'])    
df_winterthur
# Out:
#              id        lat       lon          brand         shop        city  \
# 0      70656488  47.491874  8.706448         Migros  supermarket  Winterthur
# 1     246533376  47.518953  8.720071         Migros  supermarket  Winterthur
# 2     548919417  47.506863  8.712208         Migros  supermarket  Winterthur
# 3     677194765  47.503208  8.752131           None  supermarket  Winterthur
# 4     706203439  47.500848  8.725938           None  supermarket  Winterthur
# 5     709022324  47.498421  8.729118           None  supermarket  Winterthur
# 6    1328945987  47.485289  8.762742         Migros  supermarket  Winterthur
# 7    1519474175  47.485171  8.763196         Denner  supermarket  Winterthur
# 8    3831772784  47.499163  8.721153         Migros  supermarket  Winterthur
# 9    4058248551  47.500117  8.731930         Migros  supermarket  Winterthur
# 10   4095400178  47.501547  8.747051           None  supermarket  Winterthur
# 11   4095400190  47.497901  8.724756           ALDI  supermarket  Winterthur
# 12   4109460421  47.501010  8.722078           None  supermarket  Winterthur
# 13   4125136758  47.500732  8.720169           None  supermarket  Winterthur
# 14   4189897383  47.491100  8.705538           None  supermarket  Winterthur
# 15   4209642918  47.486090  8.704346           None  supermarket  Winterthur
# 16   4379763119  47.496739  8.753231       Alnatura  supermarket  Winterthur
# 17   4471606841  47.504229  8.771731         Migros  supermarket  Winterthur
# 18   4816412575  47.510705  8.693819         Migros  supermarket  Winterthur
# 19   4978196565  47.496801  8.746607           None  supermarket  Winterthur
# 20   7418113614  47.495227  8.758614           Coop  supermarket  Winterthur
# 21   7685095602  47.495833  8.749715  Migros-Outlet  supermarket  Winterthur
# 22   8519878942  47.507437  8.754705           None  supermarket  Winterthur
# 23   9040336565  47.477343  8.699297         Migros  supermarket  Winterthur
# 24   9040336566  47.477427  8.699380         Denner  supermarket  Winterthur
# 25   9985258254  47.510886  8.759658           ALDI  supermarket  Winterthur
# 26  10221262155  47.507012  8.711808           None  supermarket  Winterthur
#
#                    street housenumber  postcode
# 0          Zürcherstrasse         102    8406.0
# 1     Schaffhauserstrasse         152    8400.0
# 2       Wülflingerstrasse          71    8400.0
# 3     Frauenfelderstrasse          69    8404.0
# 4             Bankstrasse        8/12    8400.0
# 5          Steinberggasse          18    8400.0
# 6       Hinterdorfstrasse          40    8405.0
# 7       Hinterdorfstrasse          40    8405.0
# 8         Strickerstrasse           3    8400.0
# 9        Stadthausstrasse          31    8400.0
# 10           Römerstrasse          77    8404.0
# 11              Archplatz           2    8400.0
# 12            Wartstrasse          14    8400.0
# 13       Neuwiesenstrasse           6    8400.0
# 14         Zürcherstrasse         120    8406.0
# 15              In der Au          10    8406.0
# 16       Industriestrasse          11    8400.0
# 17    Hintermühlenstrasse           4    8409.0
# 18            Lindenplatz           1    8408.0
# 19       Grüzefeldstrasse          24    8400.0
# 20  Rudolf-Diesel-Strasse          19    8404.0
# 21       Industriestrasse           8    8404.0
# 22           Römerstrasse         167    8404.0
# 23          Ziegeleiplatz           2    8406.0
# 24          Ziegeleiplatz           2    8406.0
# 25      Guggenbühlstrasse           6    8404.0
# 26      Wülflingerstrasse       73/75    8400.0

# %% [markdown]
# ## Close db connection (if open)

# %%
# Close db connection (if open)
try:
    if check_conn(conn):
        conn.close()
    else:
        pass
except:
    pass

# Status (True = open, False = closed)
print(check_conn(conn))
# Out:
# False

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1014-azure
# Datetime: 2024-09-24 12:45:52
# Python Version: 3.11.10
# -----------------------------------
