# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3435, 265)
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.diet:organic tags.diet:seafood tags.brand:website  \
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN
#
#   tags.recycling:low_energy_bulbs tags.image tags.opening_hours:cafe  \
# 0                             NaN        NaN                     NaN
# 1                             NaN        NaN                     NaN
# 2                             NaN        NaN                     NaN
# 3                             NaN        NaN                     NaN
# 4                             NaN        NaN                     NaN
#
#   tags.currency:XBT tags.payment:lightning tags.payment:lightning_contactless  \
# 0               NaN                    NaN                                NaN
# 1               NaN                    NaN                                NaN
# 2               NaN                    NaN                                NaN
# 3               NaN                    NaN                                NaN
# 4               NaN                    NaN                                NaN
#
#   tags.payment:onchain
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 265 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2c9af92b080137f2fa974851739fa7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2c9af92b080137f2fa974851739fa7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2c9af92b080137f2fa974851739fa7a = L.map(
#                 &quot;map_f2c9af92b080137f2fa974851739fa7a&quot;,
#                 {
#                     center: [47.00765045569071, 7.993251455690703],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f2c9af92b080137f2fa974851739fa7a);
#
#
#
#
#
#             var tile_layer_fa9f2ba3fadbdf1e934f05951e5e071c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fa9f2ba3fadbdf1e934f05951e5e071c.addTo(map_f2c9af92b080137f2fa974851739fa7a);
#
#
#             var marker_5bc6c7185f8207938a6c747469439074 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_f2c9af92b080137f2fa974851739fa7a);
#
#
#         var popup_73043232564c0b92e2b5ef6344bbd570 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acefcb4059acc821e80b69a555dd17c4 = $(`&lt;div id=&quot;html_acefcb4059acc821e80b69a555dd17c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_73043232564c0b92e2b5ef6344bbd570.setContent(html_acefcb4059acc821e80b69a555dd17c4);
#
#
#
#         marker_5bc6c7185f8207938a6c747469439074.bindPopup(popup_73043232564c0b92e2b5ef6344bbd570)
#         ;
#
#
#
#
#             var marker_530612ecc4d4b9e692ae5443c9480ae1 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_f2c9af92b080137f2fa974851739fa7a);
#
#
#         var popup_3f025e6e8079aecfadd07cfb5f598e91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6640da5693c12f4a4ec3449940e7c5b1 = $(`&lt;div id=&quot;html_6640da5693c12f4a4ec3449940e7c5b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_3f025e6e8079aecfadd07cfb5f598e91.setContent(html_6640da5693c12f4a4ec3449940e7c5b1);
#
#
#
#         marker_530612ecc4d4b9e692ae5443c9480ae1.bindPopup(popup_3f025e6e8079aecfadd07cfb5f598e91)
#         ;
#
#
#
#
#             var marker_f1b19580bbc1be1c453204419b6c1225 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_f2c9af92b080137f2fa974851739fa7a);
#
#
#         var popup_d86e8dd3c8c2fe1c8413d90736a8f63d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bbc2bc26874fa6274b973f81081c835 = $(`&lt;div id=&quot;html_1bbc2bc26874fa6274b973f81081c835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_d86e8dd3c8c2fe1c8413d90736a8f63d.setContent(html_1bbc2bc26874fa6274b973f81081c835);
#
#
#
#         marker_f1b19580bbc1be1c453204419b6c1225.bindPopup(popup_d86e8dd3c8c2fe1c8413d90736a8f63d)
#         ;
#
#
#
#
#             var marker_5bbd679402c1adc8a158f2467d305f4d = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_f2c9af92b080137f2fa974851739fa7a);
#
#
#         var popup_adcc24c92d2a5907f851f35f98dea624 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9550e32a29e2173c6a575de4cef63733 = $(`&lt;div id=&quot;html_9550e32a29e2173c6a575de4cef63733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_adcc24c92d2a5907f851f35f98dea624.setContent(html_9550e32a29e2173c6a575de4cef63733);
#
#
#
#         marker_5bbd679402c1adc8a158f2467d305f4d.bindPopup(popup_adcc24c92d2a5907f851f35f98dea624)
#         ;
#
#
#
#
#             var marker_49242321d5c4cb9b2577181b568ec741 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_f2c9af92b080137f2fa974851739fa7a);
#
#
#         var popup_4a2f5817691d24696e0b46ef802412ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8eb0208687999804bec912b3cb04098d = $(`&lt;div id=&quot;html_8eb0208687999804bec912b3cb04098d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_4a2f5817691d24696e0b46ef802412ad.setContent(html_8eb0208687999804bec912b3cb04098d);
#
#
#
#         marker_49242321d5c4cb9b2577181b568ec741.bindPopup(popup_4a2f5817691d24696e0b46ef802412ad)
#         ;
#
#
#
#
#             var marker_e8a4b534a3ada14f6c6915b41c15177d = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-09-17 16:24:11
# Python Version: 3.11.10
# -----------------------------------
